# %% [markdown]
# # Settings and utils

# %% [markdown]
# ## Extract type facts from a Wikipedia file
#
#
# ### === Purpose ===
#
# The goal of this lab is to extract the class to which an entity belongs from Wikipedia.
# For example, given the Wikipedia article about Leicester:
#
#     Leicester is a small city in England
#
# the goal is to extract:
#
#     Leicester TAB city
#
#
# ### === Provided Data ===
#
# We provide:
#
# 1. a preprocessed version of the Simple Wikipedia (`wikipedia-first.txt`), which looks like above
# 2. a template for your code, `extractor.py`
# 3. a gold standard sample (`gold-standard-sample.tsv`).
#
#
# ### === Task ===
#
# Complete the `extract_type()` function so that it extracts the type of the article entity from the content.
# For example, for a content of "Leicester is a beautiful English city in the UK", it should return "city".
# Exclude terms that are too abstract ("member of...", "way of..."), and try to extract exactly the noun(s).
# You can also skip articles (e.g. `return None`) if you are not sure or if the text does not contain any type.
# In order to ensure a fair evaluation, do not use any non-standard Python libraries except `nltk` (`pip install nltk`).
#
# Input:
#
# April
# April is the fourth month of the year with 30 days.
#
# Output:
# April TAB month
#
#
# ### === Development and Testing ===
#
# We provide a certain number of gold samples for validating your model.
# Finally, we calculate a F1 score using following equation:
#
# `F1 = (1 + beta * beta) * precision * recall / (beta * beta * precision + recall)`
#
# with `beta = 0.5`, putting more weight on precision in that way.

# %%
from nltk import pos_tag, download
from nltk.tokenize import word_tokenize
from nltk import RegexpParser
from nltk import Tree
download('punkt')
download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
"""
Don't modify this code.
"""

import sys


class Page:
    '''
    This class is used to store title and content of a wiki page
    '''
    __author__ = "Jonathan Lajus"

    def __init__(self, title, content):
        self.content = content
        self.title = title
        if sys.version_info[0] < 3:
            self.title = title.decode("utf-8")
            self.content = content.decode("utf-8")

    def __eq__(self, other):
        return isinstance(other, self.__class__) and self.title == other.title and self.content == other.content

    def __ne__(self, other):
        return not self.__eq__(other)

    def __hash__(self):
        return hash((self.title, self.content))

    def __str__(self):
        return 'Wikipedia page: "' + (self.title.encode("utf-8") if sys.version_info[0] < 3 else self.title) + '"'

    def __repr__(self):
        return self.__str__()

    def _to_tuple(self):
        return (self.title, self.content)


class Parsy:
    '''
    Parse a Wikipedia file, return page objects
    '''
    __author__ = "Jonathan Lajus"

    def __init__(self, wikipediaFile):
        self.file = wikipediaFile

    def __iter__(self):
        title, content = None,""
        with open(self.file, encoding='utf-8') as f:
            for line in f:
                line = line.strip()
                if not line and title is not None:
                    yield Page(title, content.rstrip())
                    title, content = None,""
                elif title is None:
                    title = line
                elif title is not None:
                    content += line + " "

    
def eval_f1(gold_file, pred_file):

    # Dictionaries
    goldstandard = dict()
    student = dict()

    # Reading first file
    with open(gold_file, 'r', encoding="utf-8") as f:
        for line in f:
            temp = line.split("\t")
            if len(temp) != 2:
                print("The line:", line, "has an incorrect number of tabs")
            else:
                if temp[0] in goldstandard:
                    print(temp[0], " has two solutions")
                goldstandard[temp[0]] = str.lower(temp[1])

    # Reading second file
    with open(pred_file, 'r', encoding="utf-8") as f:
        for line in f:
            temp = line.split("\t")
            if len(temp) != 2:
                if not debug:
                    print("Comment :=>> The line: '", line, "' has an incorrect number of tabs")
                else:
                    print("The line: '", line, "' has an incorrect number of tabs")
            else:
                if temp[0] in student:
                    if not debug:
                        print("Comment :=>>", temp[0], "has two solutions")
                    else:
                        print(temp[0], " has two solutions")
                student[temp[0]] = str.lower(temp[1])

    true_pos = 0
    false_pos = 0
    false_neg = 0

    for key in student:
        if key in goldstandard:
            if student[key] == goldstandard[key]:
                true_pos += 1
            else:
                false_pos += 1
                print("You got", key, "wrong. Expected output: ", goldstandard[key], ",given:", student[key])

    for key in goldstandard:
        if key not in student:
            false_neg += 1
            print("No solution was given for", key)

    if true_pos + false_pos != 0:
        precision = float(true_pos) / (true_pos + false_pos) * 100.0
    else:
        precision = 0.0

    if true_pos + false_neg != 0:
        recall = float(true_pos) / (true_pos + false_neg + false_pos) * 100.0
    else:
        recall = 0.0

    beta = 0.5

    if precision + recall != 0.0:
        f05 = (1 + beta * beta) * precision * recall / (beta * beta * precision + recall)
    else:
        f05 = 0.0

    # grade = 0.75 * precision + 0.25 * recall
    grade = f05

    print("Comment :=>>", "Precision:", precision, "%")
    print("Comment :=>>", "Recall:", recall, "%")
    print("Simulated Grade (F0.5) :=>>", grade, "%")

# %%
def tag_sent(sent):
  pos = pos_tag(word_tokenize(sent.lower()))
  c, p = [],[]
  for tup in pos:
    if tup[0] not in punc:
      c.append(tup[0])
      p.append(tup[1])
  return (c, p)

def intersection(lst1, lst2):
    return list(set(lst1) & set(lst2))

def find_from_pattern(pattern, token_sent):
  word = None
  PChunker = RegexpParser(pattern)
  chunk_output = PChunker.parse(pos_tag(token_sent))
  for child in chunk_output:
    if isinstance(child, Tree):               
        if child.label() == 'NP':
            for num in range(len(child)):
                if not (child[num][1]=='JJ' and child[num+1][1]=='JJ'):
                  word = child[num][0]
  return word

def get(deb, num):
  fin = deb+num
  data = {}
  i = 0
  for page in Parsy(wiki_file):
    if i>fin:
      break
    if i>deb:
      data[page.title]=page.content
    i+=1

  data_pos = {}
  for title, content in data.items():
    data_pos[title] = tag_sent(content)
  return data, data_pos

# %%
# a simplified wiki page document
wiki_file = 'wikipedia-first.txt'
# some gold samples for validation
gold_file = 'gold-standard-sample.tsv'
# predicted results generated by your model
# you are supposed to submit this file
result_file = 'results.tsv'

# %% [markdown]
# # Evaluation

# %%
def run():
    '''
    First, extract types from each sentence in the wiki file
    Next, use gold samples to evaluate your model
    :return:
    '''
    dic={}
    with open(result_file, 'w', encoding="utf-8") as output:
        for page in Parsy(wiki_file):
            typ = extract_type(page)
            if typ:
                #output.write(page.title + "\t" + typ + "\n")
                dic[page.title]=typ
    
    # Evaluate on some gold samples for checking your model
    eval_f1(gold_file, result_file)
    return dic

# %%
unwanted = ['form', 'kind', 'sort', 'type', 'way', 'part', 'name', 'piece', "asia", 'africa', 'america', 'antarctica', 'europe', 'australia', 'male', 'female', 'man', 'women', 'amount', 'something', 'word' ]
punc=['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', ' ', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~']
patterns = ["NP: {<.>?(<VBZ>|<VBP>|<VBD>)<DT>?<RB>*(<JJ>+|<JJ>?)(<NN>+|<NNS>+)}", "NP: {<DT>(<VBZ>|<VBP>|<VBD>)<CD>(<NN>+|<NNS>+)}", "NP: {(<NN>+|<NNS>+)(<VBZ>|<VBP>|<VBD>)(<NN>+|<NNS>+)<POS>(<NN>+|<NNS>+)}",
            "NP: {<NN>+(<VBZ>|<VBP>|<VBD>)<DT><JJ>(<NN>+|<NNS>+)}", "NP: {<.>?(<VBZ>|<VBP>|<VBD>)<DT><NN><IN><JJ>?(<NN>+|<NNS>+)}",
            "NP: {<TO>(<WP>|<VB>)<NN>?<VBZ><TO><VB>}", "NP: {<DT>(<NN>+|<NNS>+)(<VBZ>|<VBP>|<VBD>)<DT><``>(<NN>+|<NNS>+)}", "NP: {<DT><NN>?(<VBZ>|<VBP>|<VBD>)<DT>(<NN>+|<NNS>+)}",
            "NP: {(<NN>+|<NNS>+)(<VBZ>|<VBP>|<VBD>)<DT>(<NN>+|<NNS>+)}", "NP: {<DT>(<NN>+|<NNS>+)(<VBZ>|<VBP>|<VBD>)<VBN><TO><VB><DT>*(<NN>+|<NNS>+)}", 
            "NP: {<.>*<VBZ><DT><JJS>(<NN>+|<NNS>+)}", "NP: {<.>?(<VBZ>|<VBP>|<VBD>)<DT><JJ><NN><IN>(<NN>+|<NNS>+)}"
            ]

# %%
def extract_type(wiki_page):
    '''

    :param wiki_page is an object contains a title and the first sentence from its wiki page.
    :return:
    '''
    title = wiki_page.title
    content = wiki_page.content
    print('title: ', title)
    print('content: ', content)
    possibilities = []
    for pat in patterns:
      cont_tok = word_tokenize(content.lower())
      poss = find_from_pattern(pat, cont_tok)
      if poss!=None and poss not in unwanted and poss not in possibilities:
        possibilities.append(poss)
    typ, ind = None, 100
    for poss in possibilities:
      index = cont_tok.index(poss)
      if ind>index:
        typ, ind =poss, index
    print('ouput: ', typ)
    print('\n')  
    
    return typ

# %%
dic=run()
# Out:
# Streaming output truncated to the last 5000 lines.
# title:  Le Locheur
# content:  Le Locheur is a commune.
# ouput:  commune
#
#
# title:  Le Manoir, Calvados
# content:  Le Manoir, Calvados is a commune.
# ouput:  commune
#
#
# title:  Le Marais-la-Chapelle
# content:  Le Marais-la-Chapelle is a commune.
# ouput:  commune
#
#
# title:  Le Mesnil-Auzouf
# content:  Le Mesnil-Auzouf is a commune.
# ouput:  commune
#
#
# title:  Le Mesnil-Bacley
# content:  Le Mesnil-Bacley is a commune.
# ouput:  commune
#
#
# title:  Le Mesnil-Benoist
# content:  Le Mesnil-Benoist is a commune.
# ouput:  commune
#
#
# title:  Le Mesnil-Caussois
# content:  Le Mesnil-Caussois is a commune.
# ouput:  commune
#
#
# title:  Le Mesnil-Durand
# content:  Le Mesnil-Durand is a commune.
# ouput:  commune
#
#
# title:  Le Mesnil-Eudes
# content:  Le Mesnil-Eudes is a commune.
# ouput:  commune
#
#
# title:  Le Mesnil-Germain
# content:  Le Mesnil-Germain is a commune.
# ouput:  commune
#
#
# title:  Le Mesnil-Guillaume
# content:  Le Mesnil-Guillaume is a commune.
# ouput:  commune
#
#
# title:  Le Mesnil-Mauger
# content:  Le Mesnil-Mauger is a commune.
# ouput:  commune
#
#
# title:  Le Mesnil-Patry
# content:  Le Mesnil-Patry is a commune.
# ouput:  commune
#
#
# title:  Le Mesnil-Robert
# content:  Le Mesnil-Robert is a commune.
# ouput:  commune
#
#
# title:  Le Mesnil-Simon, Calvados
# content:  Le Mesnil-Simon, Calvados is a commune.
# ouput:  commune
#
#
# title:  Le Mesnil-Villement
# content:  Le Mesnil-Villement is a commune.
# ouput:  commune
#
#
# title:  Cafarul River
# content:  The Cafarul River is a tributary of the Valea lui Fătu River in Romania.
# ouput:  tributary
#
#
# title:  Le Mesnil-au-Grain
# content:  Le Mesnil-au-Grain is a commune.
# ouput:  commune
#
#
# title:  Le Mesnil-sur-Blangy
# content:  Le Mesnil-sur-Blangy is a commune.
# ouput:  commune
#
#
# title:  Le Molay-Littry
# content:  Le Molay-Littry is a commune.
# ouput:  commune
#
#
# title:  Le Pin, Calvados
# content:  Le Pin, Calvados is a commune.
# ouput:  commune
#
#
# title:  Le Plessis-Grimoult
# content:  Le Plessis-Grimoult is a commune.
# ouput:  commune
#
#
# title:  Le Pré-d'Auge
# content:  Le Pré-d'Auge is a commune.
# ouput:  commune
#
#
# title:  Le Reculey
# content:  Le Reculey is a commune.
# ouput:  commune
#
#
# title:  Le Theil-Bocage
# content:  Le Theil-Bocage is a commune.
# ouput:  commune
#
#
# title:  Le Theil-en-Auge
# content:  Le Theil-en-Auge is a commune.
# ouput:  commune
#
#
# title:  Le Torquesne
# content:  Le Torquesne is a commune.
# ouput:  commune
#
#
# title:  Le Tourneur
# content:  Le Tourneur is a commune.
# ouput:  commune
#
#
# title:  Le Tronquay, Calvados
# content:  Le Tronquay, Calvados is a commune.
# ouput:  commune
#
#
# title:  Le Vey
# content:  Le Vey is a commune.
# ouput:  commune
#
#
# title:  Leffard
# content:  Leffard is a commune.
# ouput:  commune
#
#
# title:  Les Autels-Saint-Bazile
# content:  Les Autels-Saint-Bazile is a commune.
# ouput:  commune
#
#
# title:  Les Authieux-Papion
# content:  Les Authieux-Papion is a commune.
# ouput:  commune
#
#
# title:  Les Authieux-sur-Calonne
# content:  Les Authieux-sur-Calonne is a commune.
# ouput:  commune
#
#
# title:  Les Isles-Bardel
# content:  Les Isles-Bardel is a commune.
# ouput:  commune
#
#
# title:  Les Loges, Calvados
# content:  Les Loges, Calvados is a commune.
# ouput:  commune
#
#
# title:  Les Loges-Saulces
# content:  Les Loges-Saulces is a commune.
# ouput:  commune
#
#
# title:  Les Monceaux
# content:  Les Monceaux is a commune.
# ouput:  commune
#
#
# title:  Les Moutiers-Hubert
# content:  Les Moutiers-Hubert is a commune.
# ouput:  commune
#
#
# title:  Lotrişorul River
# content:  The Lotrişorul River is a tributary of the Olt River in Romania.
# ouput:  tributary
#
#
# title:  Les Moutiers-en-Auge
# content:  Les Moutiers-en-Auge is a commune.
# ouput:  commune
#
#
# title:  Les Moutiers-en-Cinglais
# content:  Les Moutiers-en-Cinglais is a commune.
# ouput:  commune
#
#
# title:  Les Oubeaux
# content:  Les Oubeaux is a commune.
# ouput:  commune
#
#
# title:  Lessard-et-le-Chêne
# content:  Lessard-et-le-Chêne is a commune.
# ouput:  commune
#
#
# title:  Lingèvres
# content:  Lingèvres is a commune.
# ouput:  commune
#
#
# title:  Lion-sur-Mer
# content:  Lion-sur-Mer is a commune.
# ouput:  commune
#
#
# title:  Lisieux
# content:  Lisieux is a commune.
# ouput:  commune
#
#
# title:  Lison
# content:  Lison is a commune.
# ouput:  commune
#
#
# title:  Lisores
# content:  Lisores is a commune.
# ouput:  commune
#
#
# title:  Litteau
# content:  Litteau is a commune.
# ouput:  commune
#
#
# title:  Livarot
# content:  Livarot is a commune.
# ouput:  commune
#
#
# title:  Livry, Calvados
# content:  Livry, Calvados is a commune.
# ouput:  commune
#
#
# title:  Longraye
# content:  Longraye is a commune.
# ouput:  commune
#
#
# title:  Longues-sur-Mer
# content:  Longues-sur-Mer is a commune.
# ouput:  commune
#
#
# title:  Longueville, Calvados
# content:  Longueville, Calvados is a commune.
# ouput:  commune
#
#
# title:  Longvillers
# content:  Longvillers is a commune.
# ouput:  commune
#
#
# title:  Loucelles
# content:  Loucelles is a commune.
# ouput:  commune
#
#
# title:  Louvagny
# content:  Louvagny is a commune.
# ouput:  commune
#
#
# title:  Louvigny, Calvados
# content:  Louvigny, Calvados is a commune.
# ouput:  commune
#
#
# title:  Louvières, Calvados
# content:  Louvières, Calvados is a commune.
# ouput:  commune
#
#
# title:  Luc-sur-Mer
# content:  Luc-sur-Mer is a commune.
# ouput:  commune
#
#
# title:  Léaupartie
# content:  Léaupartie is a commune.
# ouput:  commune
#
#
# title:  Lécaude
# content:  Lécaude is a commune.
# ouput:  commune
#
#
# title:  Lénault
# content:  Lénault is a commune.
# ouput:  commune
#
#
# title:  Magny-en-Bessin
# content:  Magny-en-Bessin is a commune.
# ouput:  commune
#
#
# title:  Magny-la-Campagne
# content:  Magny-la-Campagne is a commune.
# ouput:  commune
#
#
# title:  Magny-le-Freule
# content:  Magny-le-Freule is a commune.
# ouput:  commune
#
#
# title:  Maisoncelles-Pelvey
# content:  Maisoncelles-Pelvey is a commune.
# ouput:  commune
#
#
# title:  Maisoncelles-la-Jourdan
# content:  Maisoncelles-la-Jourdan is a commune.
# ouput:  commune
#
#
# title:  Maisoncelles-sur-Ajon
# content:  Maisoncelles-sur-Ajon is a commune.
# ouput:  commune
#
#
# title:  Maisons, Calvados
# content:  Maisons, Calvados is a commune.
# ouput:  commune
#
#
# title:  Maizet
# content:  Maizet is a commune.
# ouput:  commune
#
#
# title:  Maizières, Calvados
# content:  Maizières, Calvados is a commune.
# ouput:  commune
#
#
# title:  Malloué
# content:  Malloué is a commune.
# ouput:  commune
#
#
# title:  Maltot
# content:  Maltot is a commune.
# ouput:  commune
#
#
# title:  Mandeville-en-Bessin
# content:  Mandeville-en-Bessin is a commune.
# ouput:  commune
#
#
# title:  Manerbe
# content:  Manerbe is a commune.
# ouput:  commune
#
#
# title:  Manneville-la-Pipard
# content:  Manneville-la-Pipard is a commune.
# ouput:  commune
#
#
# title:  Manvieux
# content:  Manvieux is a commune.
# ouput:  commune
#
#
# title:  Marolles, Calvados
# content:  Marolles, Calvados is a commune.
# ouput:  commune
#
#
# title:  Martainville, Calvados
# content:  Martainville, Calvados is a commune.
# ouput:  commune
#
#
# title:  Martigny-sur-l'Ante
# content:  Martigny-sur-l'Ante is a commune.
# ouput:  commune
#
#
# title:  Martragny
# content:  Martragny is a commune.
# ouput:  commune
#
#
# title:  Mathieu, Calvados
# content:  Mathieu, Calvados is a commune.
# ouput:  commune
#
#
# title:  May-sur-Orne
# content:  May-sur-Orne is a commune.
# ouput:  commune
#
#
# title:  Merville-Franceville-Plage
# content:  Merville-Franceville-Plage is a commune.
# ouput:  commune
#
#
# title:  Meslay, Calvados
# content:  Meslay, Calvados is a commune.
# ouput:  commune
#
#
# title:  Mesnil-Clinchamps
# content:  Mesnil-Clinchamps is a commune.
# ouput:  commune
#
#
# title:  Meulles
# content:  Meulles is a commune.
# ouput:  commune
#
#
# title:  Meuvaines
# content:  Meuvaines is a commune.
# ouput:  commune
#
#
# title:  Missy, Calvados
# content:  Missy, Calvados is a commune.
# ouput:  commune
#
#
# title:  Mittois
# content:  Mittois is a commune.
# ouput:  commune
#
#
# title:  Monceaux-en-Bessin
# content:  Monceaux-en-Bessin is a commune.
# ouput:  commune
#
#
# title:  Mondeville, Calvados
# content:  Mondeville, Calvados is a commune.
# ouput:  commune
#
#
# title:  Mondrainville
# content:  Mondrainville is a commune.
# ouput:  commune
#
#
# title:  Monfréville
# content:  Monfréville is a commune.
# ouput:  commune
#
#
# title:  Mont-Bertrand
# content:  Mont-Bertrand is a commune.
# ouput:  commune
#
#
# title:  Montamy
# content:  Montamy is a commune.
# ouput:  commune
#
#
# title:  Montchamp, Calvados
# content:  Montchamp, Calvados is a commune.
# ouput:  commune
#
#
# title:  Montchauvet, Calvados
# content:  Montchauvet, Calvados is a commune.
# ouput:  commune
#
#
# title:  Monteille
# content:  Monteille is a commune.
# ouput:  commune
#
#
# title:  Montfiquet
# content:  Montfiquet is a commune.
# ouput:  commune
#
#
# title:  Montigny, Calvados
# content:  Montigny, Calvados is a commune.
# ouput:  commune
#
#
# title:  Montreuil-en-Auge
# content:  Montreuil-en-Auge is a commune.
# ouput:  commune
#
#
# title:  Monts-en-Bessin
# content:  Monts-en-Bessin is a commune.
# ouput:  commune
#
#
# title:  Montviette
# content:  Montviette is a commune.
# ouput:  commune
#
#
# title:  Morteaux-Coulibœuf
# content:  Morteaux-Coulibœuf is a commune.
# ouput:  commune
#
#
# title:  Mosles
# content:  Mosles is a commune.
# ouput:  commune
#
#
# title:  Mouen
# content:  Mouen is a commune.
# ouput:  commune
#
#
# title:  Moulines, Calvados
# content:  Moulines, Calvados is a commune.
# ouput:  commune
#
#
# title:  Moult, Calvados
# content:  Moult, Calvados is a commune.
# ouput:  commune
#
#
# title:  Moyaux
# content:  Moyaux is a commune.
# ouput:  commune
#
#
# title:  Mutrécy
# content:  Mutrécy is a commune.
# ouput:  commune
#
#
# title:  Méry-Corbon
# content:  Méry-Corbon is a commune.
# ouput:  commune
#
#
# title:  Mézidon-Canon
# content:  Mézidon-Canon is a commune.
# ouput:  commune
#
#
# title:  Neuilly-la-Forêt
# content:  Neuilly-la-Forêt is a commune.
# ouput:  commune
#
#
# title:  Nonant
# content:  Nonant is a commune.
# ouput:  commune
#
#
# title:  Norolles
# content:  Norolles is a commune.
# ouput:  commune
#
#
# title:  Noron-l'Abbaye
# content:  Noron-l'Abbaye is a commune.
# ouput:  commune
#
#
# title:  Noron-la-Poterie
# content:  Noron-la-Poterie is a commune.
# ouput:  commune
#
#
# title:  Norrey-en-Auge
# content:  Norrey-en-Auge is a commune.
# ouput:  commune
#
#
# title:  Notre-Dame-d'Estrées
# content:  Notre-Dame-d'Estrées is a commune.
# ouput:  commune
#
#
# title:  Notre-Dame-de-Courson
# content:  Notre-Dame-de-Courson is a commune.
# ouput:  commune
#
#
# title:  Notre-Dame-de-Livaye
# content:  Notre-Dame-de-Livaye is a commune.
# ouput:  commune
#
#
# title:  Noyers-Bocage
# content:  Noyers-Bocage is a commune.
# ouput:  commune
#
#
# title:  Olendon
# content:  Olendon is a commune.
# ouput:  commune
#
#
# title:  Ondefontaine
# content:  Ondefontaine is a commune.
# ouput:  commune
#
#
# title:  Orbec
# content:  Orbec is a commune.
# ouput:  commune
#
#
# title:  Osmanville
# content:  Osmanville is a commune.
# ouput:  commune
#
#
# title:  Ouffières
# content:  Ouffières is a commune.
# ouput:  commune
#
#
# title:  Ouilly-du-Houley
# content:  Ouilly-du-Houley is a commune.
# ouput:  commune
#
#
# title:  Ouilly-le-Tesson
# content:  Ouilly-le-Tesson is a commune.
# ouput:  commune
#
#
# title:  Ouilly-le-Vicomte
# content:  Ouilly-le-Vicomte is a commune.
# ouput:  commune
#
#
# title:  Ouistreham
# content:  Ouistreham is a commune.
# ouput:  commune
#
#
# title:  Ouville-la-Bien-Tournée
# content:  Ouville-la-Bien-Tournée is a commune.
# ouput:  commune
#
#
# title:  Ouézy
# content:  Ouézy is a commune.
# ouput:  commune
#
#
# title:  Parfouru-sur-Odon
# content:  Parfouru-sur-Odon is a commune.
# ouput:  commune
#
#
# title:  Pennedepie
# content:  Pennedepie is a commune.
# ouput:  commune
#
#
# title:  Percy-en-Auge
# content:  Percy-en-Auge is a commune.
# ouput:  commune
#
#
# title:  Perrières
# content:  Perrières is a commune.
# ouput:  commune
#
#
# title:  Pertheville-Ners
# content:  Pertheville-Ners is a commune.
# ouput:  commune
#
#
# title:  Petiville, Calvados
# content:  Petiville, Calvados is a commune.
# ouput:  commune
#
#
# title:  Pierrefitte-en-Auge
# content:  Pierrefitte-en-Auge is a commune.
# ouput:  commune
#
#
# title:  Pierrefitte-en-Cinglais
# content:  Pierrefitte-en-Cinglais is a commune.
# ouput:  commune
#
#
# title:  Pierrepont, Calvados
# content:  Pierrepont, Calvados is a commune.
# ouput:  commune
#
#
# title:  Pierres, Calvados
# content:  Pierres, Calvados is a commune.
# ouput:  commune
#
#
# title:  Placy
# content:  Placy is a commune.
# ouput:  commune
#
#
# title:  Planquery
# content:  Planquery is a commune.
# ouput:  commune
#
#
# title:  Plumetot
# content:  Plumetot is a commune.
# ouput:  commune
#
#
# title:  Pont-Bellanger
# content:  Pont-Bellanger is a commune.
# ouput:  commune
#
#
# title:  Pont-Farcy
# content:  Pont-Farcy is a commune.
# ouput:  commune
#
#
# title:  Pont-d'Ouilly
# content:  Pont-d'Ouilly is a commune.
# ouput:  commune
#
#
# title:  Pont-l'Évêque, Calvados
# content:  Pont-l'Évêque, Calvados is a commune.
# ouput:  commune
#
#
# title:  Pontécoulant
# content:  Pontécoulant is a commune.
# ouput:  commune
#
#
# title:  Port-en-Bessin-Huppain
# content:  Port-en-Bessin-Huppain is a commune.
# ouput:  commune
#
#
# title:  Potigny
# content:  Potigny is a commune.
# ouput:  commune
#
#
# title:  Poussy-la-Campagne
# content:  Poussy-la-Campagne is a commune.
# ouput:  commune
#
#
# title:  Presles, Calvados
# content:  Presles, Calvados is a commune.
# ouput:  commune
#
#
# title:  Proussy
# content:  Proussy is a commune.
# ouput:  commune
#
#
# title:  Préaux-Bocage
# content:  Préaux-Bocage is a commune.
# ouput:  commune
#
#
# title:  Préaux-Saint-Sébastien
# content:  Préaux-Saint-Sébastien is a commune.
# ouput:  commune
#
#
# title:  Prêtreville
# content:  Prêtreville is a commune.
# ouput:  commune
#
#
# title:  Putot-en-Auge
# content:  Putot-en-Auge is a commune.
# ouput:  commune
#
#
# title:  Putot-en-Bessin
# content:  Putot-en-Bessin is a commune.
# ouput:  commune
#
#
# title:  Périers-en-Auge
# content:  Périers-en-Auge is a commune.
# ouput:  commune
#
#
# title:  Périers-sur-le-Dan
# content:  Périers-sur-le-Dan is a commune.
# ouput:  commune
#
#
# title:  Périgny, Calvados
# content:  Périgny, Calvados is a commune.
# ouput:  commune
#
#
# title:  Quetteville
# content:  Quetteville is a commune.
# ouput:  commune
#
#
# title:  Ranchy
# content:  Ranchy is a commune.
# ouput:  commune
#
#
# title:  Ranville
# content:  Ranville is a commune.
# ouput:  commune
#
#
# title:  Rapilly
# content:  Rapilly is a commune.
# ouput:  commune
#
#
# title:  Repentigny, Calvados
# content:  Repentigny, Calvados is a commune.
# ouput:  commune
#
#
# title:  Reux
# content:  Reux is a commune.
# ouput:  commune
#
#
# title:  Reviers
# content:  Reviers is a commune.
# ouput:  commune
#
#
# title:  Rocquancourt
# content:  Rocquancourt is a commune.
# ouput:  commune
#
#
# title:  Rocques
# content:  Rocques is a commune.
# ouput:  commune
#
#
# title:  Rosel
# content:  Rosel is a commune.
# ouput:  commune
#
#
# title:  Rots
# content:  Rots is a commune.
# ouput:  commune
#
#
# title:  Roucamps
# content:  Roucamps is a commune.
# ouput:  commune
#
#
# title:  Roullours
# content:  Roullours is a commune.
# ouput:  commune
#
#
# title:  Rouvres, Calvados
# content:  Rouvres, Calvados is a commune.
# ouput:  commune
#
#
# title:  Rubercy
# content:  Rubercy is a commune.
# ouput:  commune
#
#
# title:  Rucqueville
# content:  Rucqueville is a commune.
# ouput:  commune
#
#
# title:  Rully, Calvados
# content:  Rully, Calvados is a commune.
# ouput:  commune
#
#
# title:  Rumesnil
# content:  Rumesnil is a commune.
# ouput:  commune
#
#
# title:  Russy, Calvados
# content:  Russy, Calvados is a commune.
# ouput:  commune
#
#
# title:  Ryes
# content:  Ryes is a commune.
# ouput:  commune
#
#
# title:  Saint-Agnan-le-Malherbe
# content:  Saint-Agnan-le-Malherbe is a commune.
# ouput:  commune
#
#
# title:  Saint-Aignan-de-Cramesnil
# content:  Saint-Aignan-de-Cramesnil is a commune.
# ouput:  commune
#
#
# title:  Saint-André-d'Hébertot
# content:  Saint-André-d'Hébertot is a commune.
# ouput:  commune
#
#
# title:  Saint-André-sur-Orne
# content:  Saint-André-sur-Orne is a commune.
# ouput:  commune
#
#
# title:  Saint-Arnoult, Calvados
# content:  Saint-Arnoult, Calvados is a commune.
# ouput:  commune
#
#
# title:  Saint-Aubin-d'Arquenay
# content:  Saint-Aubin-d'Arquenay is a commune.
# ouput:  commune
#
#
# title:  Saint-Aubin-des-Bois, Calvados
# content:  Saint-Aubin-des-Bois, Calvados is a commune.
# ouput:  commune
#
#
# title:  Saint-Aubin-sur-Mer, Calvados
# content:  Saint-Aubin-sur-Mer, Calvados is a commune.
# ouput:  commune
#
#
# title:  Saint-Benoît-d'Hébertot
# content:  Saint-Benoît-d'Hébertot is a commune.
# ouput:  commune
#
#
# title:  Saint-Charles-de-Percy
# content:  Saint-Charles-de-Percy is a commune.
# ouput:  commune
#
#
# title:  Saint-Contest
# content:  Saint-Contest is a commune.
# ouput:  commune
#
#
# title:  Saint-Cyr-du-Ronceray
# content:  Saint-Cyr-du-Ronceray is a commune.
# ouput:  commune
#
#
# title:  Saint-Côme-de-Fresné
# content:  Saint-Côme-de-Fresné is a commune.
# ouput:  commune
#
#
# title:  Saint-Denis-Maisoncelles
# content:  Saint-Denis-Maisoncelles is a commune.
# ouput:  commune
#
#
# title:  Saint-Denis-de-Mailloc
# content:  Saint-Denis-de-Mailloc is a commune.
# ouput:  commune
#
#
# title:  Saint-Denis-de-Méré
# content:  Saint-Denis-de-Méré is a commune.
# ouput:  commune
#
#
# title:  Saint-Désir
# content:  Saint-Désir is a commune.
# ouput:  commune
#
#
# title:  Saint-Gabriel-Brécy
# content:  Saint-Gabriel-Brécy is a commune.
# ouput:  commune
#
#
# title:  Saint-Gatien-des-Bois
# content:  Saint-Gatien-des-Bois is a commune.
# ouput:  commune
#
#
# title:  Saint-Georges-d'Aunay
# content:  Saint-Georges-d'Aunay is a commune.
# ouput:  commune
#
#
# title:  Saint-Georges-en-Auge
# content:  Saint-Georges-en-Auge is a commune.
# ouput:  commune
#
#
# title:  Saint-Germain-Langot
# content:  Saint-Germain-Langot is a commune.
# ouput:  commune
#
#
# title:  Saint-Germain-d'Ectot
# content:  Saint-Germain-d'Ectot is a commune.
# ouput:  commune
#
#
# title:  Saint-Germain-de-Livet
# content:  Saint-Germain-de-Livet is a commune.
# ouput:  commune
#
#
# title:  Saint-Germain-de-Montgommery
# content:  Saint-Germain-de-Montgommery is a commune.
# ouput:  commune
#
#
# title:  Saint-Germain-de-Tallevende-la-Lande-Vaumont
# content:  Saint-Germain-de-Tallevende-la-Lande-Vaumont is a commune.
# ouput:  commune
#
#
# title:  Saint-Germain-du-Crioult
# content:  Saint-Germain-du-Crioult is a commune.
# ouput:  commune
#
#
# title:  Saint-Germain-du-Pert
# content:  Saint-Germain-du-Pert is a commune.
# ouput:  commune
#
#
# title:  Saint-Germain-la-Blanche-Herbe
# content:  Saint-Germain-la-Blanche-Herbe is a commune.
# ouput:  commune
#
#
# title:  Saint-Germain-le-Vasson
# content:  Saint-Germain-le-Vasson is a commune.
# ouput:  commune
#
#
# title:  Saint-Hymer
# content:  Saint-Hymer is a commune.
# ouput:  commune
#
#
# title:  Saint-Jean-de-Livet
# content:  Saint-Jean-de-Livet is a commune.
# ouput:  commune
#
#
# title:  Saint-Jean-des-Essartiers
# content:  Saint-Jean-des-Essartiers is a commune.
# ouput:  commune
#
#
# title:  Saint-Jean-le-Blanc, Calvados
# content:  Saint-Jean-le-Blanc, Calvados is a commune.
# ouput:  commune
#
#
# title:  Saint-Jouin
# content:  Saint-Jouin is a commune.
# ouput:  commune
#
#
# title:  Saint-Julien-de-Mailloc
# content:  Saint-Julien-de-Mailloc is a commune.
# ouput:  commune
#
#
# title:  Saint-Julien-le-Faucon
# content:  Saint-Julien-le-Faucon is a commune.
# ouput:  commune
#
#
# title:  Saint-Julien-sur-Calonne
# content:  Saint-Julien-sur-Calonne is a commune.
# ouput:  commune
#
#
# title:  Saint-Lambert, Calvados
# content:  Saint-Lambert, Calvados is a commune.
# ouput:  commune
#
#
# title:  Saint-Laurent-de-Condel
# content:  Saint-Laurent-de-Condel is a commune.
# ouput:  commune
#
#
# title:  Saint-Laurent-du-Mont
# content:  Saint-Laurent-du-Mont is a commune.
# ouput:  commune
#
#
# title:  Saint-Laurent-sur-Mer
# content:  Saint-Laurent-sur-Mer is a commune.
# ouput:  commune
#
#
# title:  Saint-Louet-sur-Seulles
# content:  Saint-Louet-sur-Seulles is a commune.
# ouput:  commune
#
#
# title:  Saint-Loup-Hors
# content:  Saint-Loup-Hors is a commune.
# ouput:  commune
#
#
# title:  Saint-Loup-de-Fribois
# content:  Saint-Loup-de-Fribois is a commune.
# ouput:  commune
#
#
# title:  Saint-Léger-Dubosq
# content:  Saint-Léger-Dubosq is a commune.
# ouput:  commune
#
#
# title:  Saint-Manvieu-Bocage
# content:  Saint-Manvieu-Bocage is a commune.
# ouput:  commune
#
#
# title:  Saint-Manvieu-Norrey
# content:  Saint-Manvieu-Norrey is a commune.
# ouput:  commune
#
#
# title:  Saint-Marcouf, Calvados
# content:  Saint-Marcouf, Calvados is a commune.
# ouput:  commune
#
#
# title:  Saint-Martin-Don
# content:  Saint-Martin-Don is a commune.
# ouput:  commune
#
#
# title:  Saint-Martin-aux-Chartrains
# content:  Saint-Martin-aux-Chartrains is a commune.
# ouput:  commune
#
#
# title:  Saint-Martin-de-Bienfaite-la-Cressonnière
# content:  Saint-Martin-de-Bienfaite-la-Cressonnière is a commune.
# ouput:  commune
#
#
# title:  Common cuckoo
# content:  The Common Cuckoo  is a well known bird in many parts of the world.
# ouput:  None
#
#
# title:  Saint-Martin-de-Blagny
# content:  Saint-Martin-de-Blagny is a commune.
# ouput:  commune
#
#
# title:  Saint-Martin-de-Fontenay
# content:  Saint-Martin-de-Fontenay is a commune.
# ouput:  commune
#
#
# title:  Saint-Martin-de-Mailloc
# content:  Saint-Martin-de-Mailloc is a commune.
# ouput:  commune
#
#
# title:  Saint-Martin-de-Mieux
# content:  Saint-Martin-de-Mieux is a commune.
# ouput:  commune
#
#
# title:  Saint-Martin-de-Sallen
# content:  Saint-Martin-de-Sallen is a commune.
# ouput:  commune
#
#
# title:  Saint-Martin-de-la-Lieue
# content:  Saint-Martin-de-la-Lieue is a commune.
# ouput:  commune
#
#
# title:  Saint-Martin-des-Besaces
# content:  Saint-Martin-des-Besaces is a commune.
# ouput:  commune
#
#
# title:  Saint-Martin-des-Entrées
# content:  Saint-Martin-des-Entrées is a commune.
# ouput:  commune
#
#
# title:  Saint-Martin-du-Mesnil-Oury
# content:  Saint-Martin-du-Mesnil-Oury is a commune.
# ouput:  commune
#
#
# title:  Saint-Michel-de-Livet
# content:  Saint-Michel-de-Livet is a commune.
# ouput:  commune
#
#
# title:  Saint-Omer, Calvados
# content:  Saint-Omer, Calvados is a commune.
# ouput:  commune
#
#
# title:  Saint-Ouen-des-Besaces
# content:  Saint-Ouen-des-Besaces is a commune.
# ouput:  commune
#
#
# title:  Saint-Ouen-du-Mesnil-Oger
# content:  Saint-Ouen-du-Mesnil-Oger is a commune.
# ouput:  commune
#
#
# title:  Saint-Ouen-le-Houx
# content:  Saint-Ouen-le-Houx is a commune.
# ouput:  commune
#
#
# title:  Saint-Ouen-le-Pin
# content:  Saint-Ouen-le-Pin is a commune.
# ouput:  commune
#
#
# title:  Saint-Pair
# content:  Saint-Pair is a commune.
# ouput:  commune
#
#
# title:  Saint-Paul-du-Vernay
# content:  Saint-Paul-du-Vernay is a commune.
# ouput:  commune
#
#
# title:  Saint-Philbert-des-Champs
# content:  Saint-Philbert-des-Champs is a commune.
# ouput:  commune
#
#
# title:  Saint-Pierre-Azif
# content:  Saint-Pierre-Azif is a commune.
# ouput:  commune
#
#
# title:  Saint-Pierre-Canivet
# content:  Saint-Pierre-Canivet is a commune.
# ouput:  commune
#
#
# title:  Saint-Pierre-Tarentaine
# content:  Saint-Pierre-Tarentaine is a commune.
# ouput:  commune
#
#
# title:  Saint-Pierre-de-Mailloc
# content:  Saint-Pierre-de-Mailloc is a commune.
# ouput:  commune
#
#
# title:  Saint-Pierre-des-Ifs, Calvados
# content:  Saint-Pierre-des-Ifs, Calvados is a commune.
# ouput:  commune
#
#
# title:  Saint-Pierre-du-Bû
# content:  Saint-Pierre-du-Bû is a commune.
# ouput:  commune
#
#
# title:  Saint-Pierre-du-Fresne
# content:  Saint-Pierre-du-Fresne is a commune.
# ouput:  commune
#
#
# title:  Saint-Pierre-du-Jonquet
# content:  Saint-Pierre-du-Jonquet is a commune.
# ouput:  commune
#
#
# title:  Saint-Pierre-du-Mont, Calvados
# content:  Saint-Pierre-du-Mont, Calvados is a commune.
# ouput:  commune
#
#
# title:  Saint-Pierre-la-Vieille
# content:  Saint-Pierre-la-Vieille is a commune.
# ouput:  commune
#
#
# title:  Saint-Pierre-sur-Dives
# content:  Saint-Pierre-sur-Dives is a commune.
# ouput:  commune
#
#
# title:  Saint-Rémy, Calvados
# content:  Saint-Rémy, Calvados is a commune.
# ouput:  commune
#
#
# title:  Saint-Samson, Calvados
# content:  Saint-Samson, Calvados is a commune.
# ouput:  commune
#
#
# title:  Saint-Sever-Calvados
# content:  Saint-Sever-Calvados is a commune.
# ouput:  commune
#
#
# title:  Saint-Sylvain, Calvados
# content:  Saint-Sylvain, Calvados is a commune.
# ouput:  commune
#
#
# title:  Saint-Vaast-en-Auge
# content:  Saint-Vaast-en-Auge is a commune.
# ouput:  commune
#
#
# title:  Saint-Vaast-sur-Seulles
# content:  Saint-Vaast-sur-Seulles is a commune.
# ouput:  commune
#
#
# title:  Saint-Vigor-des-Mézerets
# content:  Saint-Vigor-des-Mézerets is a commune.
# ouput:  commune
#
#
# title:  Saint-Vigor-le-Grand
# content:  Saint-Vigor-le-Grand is a commune.
# ouput:  commune
#
#
# title:  Saint-Étienne-la-Thillaye
# content:  Saint-Étienne-la-Thillaye is a commune.
# ouput:  commune
#
#
# title:  Sainte-Croix-Grand-Tonne
# content:  Sainte-Croix-Grand-Tonne is a commune.
# ouput:  commune
#
#
# title:  Sainte-Croix-sur-Mer
# content:  Sainte-Croix-sur-Mer is a commune.
# ouput:  commune
#
#
# title:  Sainte-Foy-de-Montgommery
# content:  Sainte-Foy-de-Montgommery is a commune.
# ouput:  commune
#
#
# title:  Sainte-Honorine-de-Ducy
# content:  Sainte-Honorine-de-Ducy is a commune.
# ouput:  commune
#
#
# title:  Sainte-Honorine-des-Pertes
# content:  Sainte-Honorine-des-Pertes is a commune.
# ouput:  commune
#
#
# title:  Sainte-Honorine-du-Fay
# content:  Sainte-Honorine-du-Fay is a commune.
# ouput:  commune
#
#
# title:  Sainte-Marguerite-d'Elle
# content:  Sainte-Marguerite-d'Elle is a commune.
# ouput:  commune
#
#
# title:  Sainte-Marguerite-de-Viette
# content:  Sainte-Marguerite-de-Viette is a commune.
# ouput:  commune
#
#
# title:  Sainte-Marguerite-des-Loges
# content:  Sainte-Marguerite-des-Loges is a commune.
# ouput:  commune
#
#
# title:  Sainte-Marie-Laumont
# content:  Sainte-Marie-Laumont is a commune.
# ouput:  commune
#
#
# title:  Sainte-Marie-Outre-l'Eau
# content:  Sainte-Marie-Outre-l'Eau is a commune.
# ouput:  commune
#
#
# title:  Sallen
# content:  Sallen is a commune.
# ouput:  commune
#
#
# title:  Sallenelles
# content:  Sallenelles is a commune.
# ouput:  commune
#
#
# title:  Sannerville
# content:  Sannerville is a commune.
# ouput:  commune
#
#
# title:  Saon
# content:  Saon is a commune.
# ouput:  commune
#
#
# title:  Saonnet
# content:  Saonnet is a commune.
# ouput:  commune
#
#
# title:  Sassy, Calvados
# content:  Sassy, Calvados is a commune.
# ouput:  commune
#
#
# title:  Secqueville-en-Bessin
# content:  Secqueville-en-Bessin is a commune.
# ouput:  commune
#
#
# title:  Sept-Frères
# content:  Sept-Frères is a commune.
# ouput:  commune
#
#
# title:  Sept-Vents
# content:  Sept-Vents is a commune.
# ouput:  commune
#
#
# title:  Soignolles
# content:  Soignolles is a commune.
# ouput:  commune
#
#
# title:  Soliers
# content:  Soliers is a commune.
# ouput:  commune
#
#
# title:  Sommervieu
# content:  Sommervieu is a commune.
# ouput:  commune
#
#
# title:  Soulangy
# content:  Soulangy is a commune.
# ouput:  commune
#
#
# title:  Soumont-Saint-Quentin
# content:  Soumont-Saint-Quentin is a commune.
# ouput:  commune
#
#
# title:  Subles
# content:  Subles is a commune.
# ouput:  commune
#
#
# title:  Sully, Calvados
# content:  Sully, Calvados is a commune.
# ouput:  commune
#
#
# title:  Surrain
# content:  Surrain is a commune.
# ouput:  commune
#
#
# title:  Surville, Calvados
# content:  Surville, Calvados is a commune.
# ouput:  commune
#
#
# title:  Tessel
# content:  Tessel is a commune.
# ouput:  commune
#
#
# title:  Thaon
# content:  Thaon is a commune.
# ouput:  commune
#
#
# title:  Thiéville
# content:  Thiéville is a commune.
# ouput:  commune
#
#
# title:  Thury-Harcourt
# content:  Thury-Harcourt is a commune.
# ouput:  commune
#
#
# title:  Tierceville
# content:  Tierceville is a commune.
# ouput:  commune
#
#
# title:  Tilly-la-Campagne
# content:  Tilly-la-Campagne is a commune.
# ouput:  commune
#
#
# title:  Tilly-sur-Seulles
# content:  Tilly-sur-Seulles is a commune.
# ouput:  commune
#
#
# title:  Tordouet
# content:  Tordouet is a commune.
# ouput:  commune
#
#
# title:  Torteval-Quesnay
# content:  Torteval-Quesnay is a commune.
# ouput:  commune
#
#
# title:  Tortisambert
# content:  Tortisambert is a commune.
# ouput:  commune
#
#
# title:  Touffréville
# content:  Touffréville is a commune.
# ouput:  commune
#
#
# title:  Touques, Calvados
# content:  Touques, Calvados is a commune.
# ouput:  commune
#
#
# title:  Tour-en-Bessin
# content:  Tour-en-Bessin is a commune.
# ouput:  commune
#
#
# title:  Tourgéville
# content:  Tourgéville is a commune.
# ouput:  commune
#
#
# title:  Tournay-sur-Odon
# content:  Tournay-sur-Odon is a commune.
# ouput:  commune
#
#
# title:  Tournebu
# content:  Tournebu is a commune.
# ouput:  commune
#
#
# title:  Tournières
# content:  Tournières is a commune.
# ouput:  commune
#
#
# title:  Tourville-en-Auge
# content:  Tourville-en-Auge is a commune.
# ouput:  commune
#
#
# title:  Tourville-sur-Odon
# content:  Tourville-sur-Odon is a commune.
# ouput:  commune
#
#
# title:  Tracy-Bocage
# content:  Tracy-Bocage is a commune.
# ouput:  commune
#
#
# title:  Tracy-sur-Mer
# content:  Tracy-sur-Mer is a commune.
# ouput:  commune
#
#
# title:  Troarn
# content:  Troarn is a commune.
# ouput:  commune
#
#
# title:  Trois-Monts
# content:  Trois-Monts is a commune.
# ouput:  commune
#
#
# title:  Trouville-sur-Mer
# content:  Trouville-sur-Mer is a commune.
# ouput:  commune
#
#
# title:  Trungy
# content:  Trungy is a commune.
# ouput:  commune
#
#
# title:  Truttemer-le-Grand
# content:  Truttemer-le-Grand is a commune.
# ouput:  commune
#
#
# title:  Truttemer-le-Petit
# content:  Truttemer-le-Petit is a commune.
# ouput:  commune
#
#
# title:  Tréprel
# content:  Tréprel is a commune.
# ouput:  commune
#
#
# title:  Trévières
# content:  Trévières is a commune.
# ouput:  commune
#
#
# title:  Urville, Calvados
# content:  Urville, Calvados is a commune.
# ouput:  commune
#
#
# title:  Ussy
# content:  Ussy is a commune.
# ouput:  commune
#
#
# title:  Vacognes-Neuilly
# content:  Vacognes-Neuilly is a commune.
# ouput:  commune
#
#
# title:  Valsemé
# content:  Valsemé is a commune.
# ouput:  commune
#
#
# title:  Varaville
# content:  Varaville is a commune.
# ouput:  commune
#
#
# title:  Vassy, Calvados
# content:  Vassy, Calvados is a commune.
# ouput:  commune
#
#
# title:  Vaubadon
# content:  Vaubadon is a commune.
# ouput:  commune
#
#
# title:  Vaucelles
# content:  Vaucelles is a commune.
# ouput:  commune
#
#
# title:  Vaudeloges
# content:  Vaudeloges is a commune.
# ouput:  commune
#
#
# title:  Vaudry
# content:  Vaudry is a commune.
# ouput:  commune
#
#
# title:  Vauville, Calvados
# content:  Vauville, Calvados is a commune.
# ouput:  commune
#
#
# title:  Vaux-sur-Aure
# content:  Vaux-sur-Aure is a commune.
# ouput:  commune
#
#
# title:  Vaux-sur-Seulles
# content:  Vaux-sur-Seulles is a commune.
# ouput:  commune
#
#
# title:  Găvan River (Olt)
# content:  The Găvan River is a tributary of the Olt River in Romania.
# ouput:  tributary
#
#
# title:  Vendes
# content:  Vendes is a commune.
# ouput:  commune
#
#
# title:  Vendeuvre
# content:  Vendeuvre is a commune.
# ouput:  commune
#
#
# title:  Ver-sur-Mer
# content:  Ver-sur-Mer is a commune.
# ouput:  commune
#
#
# title:  Versainville
# content:  Versainville is a commune.
# ouput:  commune
#
#
# title:  Verson
# content:  Verson is a commune.
# ouput:  commune
#
#
# title:  Vicques, Calvados
# content:  Vicques, Calvados is a commune.
# ouput:  commune
#
#
# title:  Victot-Pontfol
# content:  Victot-Pontfol is a commune.
# ouput:  commune
#
#
# title:  Vienne-en-Bessin
# content:  Vienne-en-Bessin is a commune.
# ouput:  commune
#
#
# title:  Vierville-sur-Mer
# content:  Vierville-sur-Mer is a commune.
# ouput:  commune
#
#
# title:  Viessoix
# content:  Viessoix is a commune.
# ouput:  commune
#
#
# title:  Vieux, Calvados
# content:  Vieux, Calvados is a commune.
# ouput:  commune
#
#
# title:  Vieux-Bourg
# content:  Vieux-Bourg is a commune.
# ouput:  commune
#
#
# title:  Vieux-Fumé
# content:  Vieux-Fumé is a commune.
# ouput:  commune
#
#
# title:  Vieux-Pont-en-Auge
# content:  Vieux-Pont-en-Auge is a commune.
# ouput:  commune
#
#
# title:  Vignats
# content:  Vignats is a commune.
# ouput:  commune
#
#
# title:  Villers-Bocage, Calvados
# content:  Villers-Bocage, Calvados is a commune.
# ouput:  commune
#
#
# title:  Raţa River (Olt)
# content:  The Raţa River is a tributary of the Olt River in Romania.
# ouput:  tributary
#
#
# title:  Villers-Canivet
# content:  Villers-Canivet is a commune.
# ouput:  commune
#
#
# title:  Villers-sur-Mer
# content:  Villers-sur-Mer is a commune.
# ouput:  commune
#
#
# title:  Villerville
# content:  Villerville is a commune.
# ouput:  commune
#
#
# title:  Villiers-le-Sec, Calvados
# content:  Villiers-le-Sec, Calvados is a commune.
# ouput:  commune
#
#
# title:  Villons-les-Buissons
# content:  Villons-les-Buissons is a commune.
# ouput:  commune
#
#
# title:  Villy-Bocage
# content:  Villy-Bocage is a commune.
# ouput:  commune
#
#
# title:  Moaşa River (Olt)
# content:  The Moaşa River or Moaşa Sebeşului River is a tributary of the Olt River in Romania.
# ouput:  tributary
#
#
# title:  Osetul River
# content:  The Osetul River is a tributary of the Moaşa River in Romania.
# ouput:  tributary
#
#
# title:  Villy-lez-Falaise
# content:  Villy-lez-Falaise is a commune.
# ouput:  commune
#
#
# title:  Vimont, Calvados
# content:  Vimont, Calvados is a commune.
# ouput:  commune
#
#
# title:  Vire
# content:  Vire is a commune.
# ouput:  commune
#
#
# title:  Vouilly
# content:  Vouilly is a commune.
# ouput:  commune
#
#
# title:  Écrammeville
# content:  Écrammeville is a commune.
# ouput:  commune
#
#
# title:  Émiéville
# content:  Émiéville is a commune.
# ouput:  commune
#
#
# title:  Épaney
# content:  Épaney is a commune.
# ouput:  commune
#
#
# title:  Épinay-sur-Odon
# content:  Épinay-sur-Odon is a commune.
# ouput:  commune
#
#
# title:  Épron
# content:  Épron is a commune.
# ouput:  commune
#
#
# title:  Équemauville
# content:  Équemauville is a commune.
# ouput:  commune
#
#
# title:  Éterville
# content:  Éterville is a commune.
# ouput:  commune
#
#
# title:  Valea Tătarului River
# content:  The Valea Tătarului River or Tătaru River is a tributary of the Moaşa River in Romania.
# ouput:  tributary
#
#
# title:  Étouvy
# content:  Étouvy is a commune.
# ouput:  commune
#
#
# title:  Étréham
# content:  Étréham is a commune.
# ouput:  commune
#
#
# title:  Évrecy
# content:  Évrecy is a commune.
# ouput:  commune
#
#
# title:  Southern Railway (Great Britain)
# content:  The Southern Railway , was a British railway company established in the 1923 Grouping.
# ouput:  company
#
#
# title:  Electric multiple unit
# content:  An electric multiple unit or EMU is a multiple unit train consisting of many carriages using electricity as the motive power.
# ouput:  train
#
#
# title:  List of British Rail modern traction locomotive classes
# content:  This page lists every locomotive allocated a TOPS classification and all modern traction (e.g.
# ouput:  locomotive
#
#
# title:  List of British Rail diesel multiple unit classes
# content:  This is a list of British Rail diesel multiple unit classes.
# ouput:  list
#
#
# title:  List of British Rail electric multiple unit classes
# content:  This page lists every electric-powered multiple unit allocated a TOPS classification or used on the mainline network since 1948 .
# ouput:  classification
#
#
# title:  List of British Rail departmental multiple unit classes
# content:  The 900 series classes were reserved for multiple units in departmental stock, most of which were converted from old passenger units.
# ouput:  None
#
#
# title:  British United Traction
# content:  British United Traction  was a joint company owned by the Associated Equipment Company and Leyland Motors which produced railway equipment and trolleybuses.
# ouput:  company
#
#
# title:  British Rail Derby Lightweight
# content:  The British Rail Derby Lightweight diesel multiple units, were the first such trains to be built en-masse for British Railways.
# ouput:  trains
#
#
# title:  British Rail Metro-Cammell
# content:  In 1955, Metropolitan Cammell produced its first lightweight Diesel multiple units, the prototypes of what were to become British Rail's most successful and longest-lived "First Generation" DMU type, the Class 101.
# ouput:  None
#
#
# title:  British Rail Railbuses
# content:  British Rail produced a variety of Railbuses as a means both of building new rolling stock cheaply, and to provide services on lightly-used lines economically.
# ouput:  variety
#
#
# title:  GWR railcars
# content:  In 1933, the Great Western Railway introduced the first of what was to become a very successful series of railcars, which survived in regular use into the 1960s, when they were replaced with the new British Rail "first generation" type diesel multiple units.
# ouput:  None
#
#
# title:  LMS railcars
# content:  The London Midland and Scottish Railway  introduced a number of railcars to service between 1933 and 1939.
# ouput:  number
#
#
# title:  Pacer (train)
# content:  Pacer is the operational name of the British Rail Class 140, 141, 142, 143 and 144 diesel multiple unit railbuses, built between 1984 and 1987.
# ouput:  None
#
#
# title:  Sprinter (train)
# content:  The Sprinter is a family of diesel multiple unit trains in use on the UK railway system.
# ouput:  family
#
#
# title:  Turbostar
# content:  Turbostar is the name given to a series of diesel multiple units  built by Bombardier Transportation  at their Litchurch Lane Works in Derby, England.
# ouput:  None
#
#
# title:  Coradia (train)
# content:  Coradia is the name given to the range of multiple-unit inter-city and regional trains manufactured by Alstom.
# ouput:  None
#
#
# title:  Bombardier Voyager family
# content:  The Voyager series is a group of high speed diesel electric multiple unit trains built by Bombardier Transportation in service on the UK railway network.
# ouput:  group
#
#
# title:  Diesel multiple unit
# content:  A diesel multiple unit or DMU is a multiple unit train consisting of multiple carriages powered by one or more on-board diesel engines.
# ouput:  consisting
#
#
# title:  British Rail Janus
# content:  Janus and Taurus were two shunting locomotives by the Yorkshire Engine Company and loaned to British Railways for demonstrations.
# ouput:  None
#
#
# title:  British Rail HS4000
# content:  HS4000, named "Kestrel", was a prototype high-powered mainline diesel locomotive built in 1968 by Brush Traction, Loughborough to demonstrate its wares to British Railways.
# ouput:  diesel
#
#
# title:  8667 Fontane
# content:  8667 Fontane  is a Main-belt Asteroid that was found on April 9, 1991 by F.
# ouput:  asteroid
#
#
# title:  8672 Morse
# content:  8672 Morse  is a Main-belt Asteroid that was found on August 6, 1991 by Eric Walter Elst at the European Southern Observatory.
# ouput:  asteroid
#
#
# title:  7455 Podosek
# content:  7455 Podosek  is a Main-belt Asteroid that was found on March 2, 1981 by S.
# ouput:  asteroid
#
#
# title:  7544 Tipografiyanauka
# content:  7544 Tipografiyanauka  is a Main-belt Asteroid that was found on October 26, 1976 by T.
# ouput:  asteroid
#
#
# title:  7347 Vickyhamilton
# content:  is a main belt asteroid that was found on November 3, 1988.
# ouput:  asteroid
#
#
# title:  British Rail GT3
# content:  GT3, meaning Gas Turbine number 3 , was a prototype mainline gas turbine locomotive built in 1961 by English Electric at their Vulcan Foundry in Newton-le-Willows to demonstrate its wares to British Railways.
# ouput:  locomotive
#
#
# title:  British Rail DP2
# content:  DP2, meaning Diesel Prototype number 2, was a prototype Type 4 mainline diesel locomotive built in 1962 by English Electric at their Vulcan Foundry in Newton-le-Willows to demonstrate its wares to British Railways.
# ouput:  None
#
#
# title:  British Rail DP1
# content:  DP1, or Prototype Deltic is a demonstrator locomotive built by English Electric in 1955.
# ouput:  demonstrator
#
#
# title:  British Rail DHP1
# content:  DHP1, meaning Diesel Hydraulic Prototype number 1, was a prototype Type 3 mainline diesel locomotive built in 1965 by Clayton to demonstrate their wares to British Railways.
# ouput:  None
#
#
# title:  British Rail D0260
# content:  D0260, named "Lion", was a prototype Type 4 mainline diesel locomotive built in 1962 by the Birmingham Railway Carriage and Wagon Company, in association with Sulzer and Associated Electrical Industries, at their Smethwick works in Birmingham to demonstrate their wares to British Railways.
# ouput:  None
#
#
# title:  British Railways D0226
# content:  D0226 and D0227 were two prototype diesel shunting locomotives built in 1956 by English Electric at its Vulcan Foundry in Newton-le-Willows to demonstrate its wares to British Railways.
# ouput:  None
#
#
# title:  British Rail 18100
# content:  British Rail 18100 was a prototype main line gas turbine-electric locomotive built for British Railways in 1951 by Metropolitan Vickers, Manchester.
# ouput:  prototype
#
#
# title:  British Rail 18000
# content:  British Rail 18000 was a prototype mainline Gas turbine-electric locomotive built for British Railways in 1949 by Brown, Boveri & Cie.
# ouput:  gas
#
#
# title:  LNER Class Y11
# content:  LNER Class Y11 was a class of petrol powered 0-4-0 locomotives built by Motor Rail & Tram Car Company Limited under their "Simplex" brand and introduced in the years 1919-1925 for the London and North Eastern Railway .
# ouput:  class
#
#
# title:  British Rail Class 97
# content:  British Rail reserved the TOPS Class 97 designation for departmental locomotives.
# ouput:  tops
#
#
# title:  British Rail Class 97/6
# content:  The British Rail Class 97/6 0-6-0 diesel shunting locomotives were purpose-built for departmental duties by Ruston & Hornsby at Lincoln in 1953  or 1959 .
# ouput:  None
#
#
# title:  British Rail Eastern Region departmental locomotives
# content:  In 1952, the Eastern Region of British Rail introduced its own series for departmental  vehicles, including locomotives.
# ouput:  None
#
#
# title:  SR departmental locomotives
# content:  The Southern Railway numbered its departmental  stock, both locomotives and carriages in a series commencing at 1S.
# ouput:  None
#
#
# title:  British Rail Class ES1
# content:  British Rail Class ES1 was a class of two electric locomotives commissioned by the North Eastern Railway in 1902.
# ouput:  class
#
#
# title:  British Rail Class EF1
# content:  The British Rail Class EF1  was a class of electrically powered locomotives used by British Rail in England.
# ouput:  class
#
#
# title:  British Rail Class EE1
# content:  British Rail Class EE1 was an electric locomotive commissioned by the North Eastern Railway in 1922.
# ouput:  locomotive
#
#
# title:  British Rail Class EB1
# content:  The British Rail Class EB1  was an electrically powered locomotive used by British Rail in England.
# ouput:  locomotive
#
#
# title:  SNCF Class BB 22200
# content:  The BB 22200 is a class of electric locomotives in service with the French railways SNCF, built by Alsthom between 1976-1986.
# ouput:  class
#
#
# title:  Vossloh G1206
# content:  The Vossloh G1206 is a B'B' diesel hydraulic freight locomotive built by Vossloh and used by several mainland European railway operators.
# ouput:  b'b
#
#
# title:  British Rail Class 41 (HST)
# content:  The British Rail Class 41 was the original classification for the power cars of the prototype High Speed Train.
# ouput:  classification
#
#
# title:  British Rail Class 43 (Warship Class)
# content:  The British Rail Class 43 diesel-hydraulic locomotives were built by the North British Locomotive Company  from 1960-1962.
# ouput:  None
#
#
# title:  British Rail Class 43 (HST)
# content:  The British Rail Class 43 is the classification used for the InterCity 125 High Speed Train power cars, built by BREL from 1976 to 1982.
# ouput:  power
#
#
# title:  North Midland Railway
# content:  The North Midland Railway was a British railway company, which opened its line from Derby to Rotherham  and Leeds in 1840.
# ouput:  company
#
#
# title:  Glasgow Corporation Tramways
# content:  Glasgow Corporation Tramways were formerly one of the largest urban tramway systems in Europe.
# ouput:  None
#
#
# title:  Southampton 45
# content:  This was the tram that started the whole preservation movement when it was purchased in 1949 after a final tour of the Southampton system before closure.
# ouput:  tram
#
#
# title:  Acanthocephala
# content:  The Acanthocephala  is a phylum of parasitic worms known as acanthocephales, thorny-headed worms, or spiny-headed worms, characterised by the presence of an evertable proboscis, armed with spines, which it uses to pierce and hold the gut wall of its host.
# ouput:  phylum
#
#
# title:  Second Polish Republic
# content:  Second Polish Republic was name of Polish state from 1918  through 1939 .
# ouput:  None
#
#
# title:  Ze (Cyrillic)
# content:  Ze  is the eighth letter in the Cyrillic alphabet.
# ouput:  letter
#
#
# title:  I (Cyrillic)
# content:  I  is the ninth letter in the Cyrillic alphabet.
# ouput:  letter
#
#
# title:  Kirkby Lonsdale
# content:  Kirkby Lonsdale is a small town in Cumbria, England.
# ouput:  town
#
#
# title:  Windermere
# content:  Windermere is the largest natural lake in England.
# ouput:  None
#
#
# title:  Hippolytushoef
# content:  Hippolytushoef  is a town in the Dutch province of North Holland.
# ouput:  town
#
#
# title:  Storm drain
# content:  A storm drain, storm sewer , stormwater drain  or surface water system  is designed to drain extra rain and ground water from paved streets, parking lots, sidewalks, and roofs.
# ouput:  None
#
#
# title:  Jet stream
# content:  Jet streams are fast flowing, relatively narrow air currents found at the tropopause, the transition between the troposphere  and the stratosphere , and are located at 10-15 kilometers above the surface of the Earth.
# ouput:  flowing
#
#
# title:  Hiroki Ito
# content:  Hiroki Ito  is a Japanese football player.
# ouput:  player
#
#
# title:  Noritada Saneyoshi
# content:  Noritada Saneyoshi  is a former Japanese football player.
# ouput:  player
#
#
# title:  Nobuyuki Furo
# content:  Nobuyuki Furo  is a former Japanese football player.
# ouput:  player
#
#
# title:  Hitoshi Sogahata
# content:  Hitoshi Sogahata  is a Japanese football player.
# ouput:  player
#
#
# title:  Justice Christopher
# content:  Justice Christopher  is a former football player.
# ouput:  player
#
#
# title:  Haruna Babangida
# content:  Haruna Babangida  is a football player.
# ouput:  player
#
#
# title:  Guus Hiddink
# content:  Guus Hiddink  is a former Dutch football player.
# ouput:  player
#
#
# title:  Hiromi Hara
# content:  Hiromi Hara  is a former Japanese football player.
# ouput:  player
#
#
# title:  Naohiro Ishikawa
# content:  Naohiro Ishikawa  is a former Japanese football player.
# ouput:  player
#
#
# title:  Yukihiko Sato
# content:  Yukihiko Sato  is a Japanese football player.
# ouput:  player
#
#
# title:  Eisuke Nakanishi
# content:  Eisuke Nakanishi  is a former Japanese football player.
# ouput:  player
#
#
# title:  Yutaro Abe
# content:  Yutaro Abe  is a Japanese football player.
# ouput:  player
#
#
# title:  Tatsuya Enomoto
# content:  Tatsuya Enomoto  is a Japanese football player.
# ouput:  player
#
#
# title:  Daisuke Nasu
# content:  Daisuke Nasu  is a Japanese football player.
# ouput:  player
#
#
# title:  H.N.K. Hajduk Split
# content:  H.N.K.
# ouput:  None
#
#
# title:  N.K. Dinamo Zagreb
# content:  N.K.
# ouput:  None
#
#
# title:  N.K. Zagreb
# content:  N.K.
# ouput:  None
#
#
# title:  Michael I of Romania
# content:  Michael, King of the Romanians, Prince of Hohenzollern , reigned as King of the Romanians  from July 20, 1927 to June 8, 1930, and again from September 6, 1940, until forced to abdicate by the communists backed up by orders of Stalin to the Soviet armies of occupation on December 30, 1947.
# ouput:  None
#
#
# title:  13063 Purifoy
# content:  13063 Purifoy  is a Main-belt Asteroid that was found on June 5, 1991 by Spacewatch at Kitt Peak.
# ouput:  asteroid
#
#
# title:  13070 Seanconnery
# content:  13070 Seanconnery is a Main Belt asteroid that was found on September 8, 1991 by Eric Walter Elst.
# ouput:  asteroid
#
#
# title:  13084 Virchow
# content:  is a main belt asteroid that was found on April 2, 1992.
# ouput:  asteroid
#
#
# title:  13052 Las Casas
# content:  13052 Las Casas  is a Main-belt Asteroid that was found on September 22, 1990 by E.
# ouput:  asteroid
#
#
# title:  13055 Kreppein
# content:  13055 Kreppein  is a Main-belt Asteroid that was found on October 14, 1990 by L.
# ouput:  asteroid
#
#
# title:  13057 Jorgensen
# content:  13057 Jorgensen  is a Main-belt Asteroid that was found on November 13, 1990 by C.
# ouput:  asteroid
#
#
# title:  13059 Ducuroir
# content:  13059 Ducuroir  is a Main-belt Asteroid that was found on January 18, 1991 by E.
# ouput:  asteroid
#
#
# title:  13062 Podarkes
# content:  13062 Podarkes  is a Jupiter Trojan that was found on April 19, 1991 by C.
# ouput:  trojan
#
#
# title:  13121 Tisza
# content:  13121 Tisza  is a Main-belt Asteroid that was found on February 7, 1994 by E.
# ouput:  asteroid
#
#
# title:  13123 Tyson
# content:  13123 Tyson  is a Main-belt Asteroid that was found on May 16, 1994 by C.
# ouput:  asteroid
#
#
# title:  13125 Tobolsk
# content:  13125 Tobolsk  is a Main-belt Asteroid that was found on August 10, 1994 by E.
# ouput:  asteroid
#
#
# title:  21290 Vydra
# content:  is a main belt asteroid that was found on November 9, 1996.
# ouput:  asteroid
#
#
# title:  9313 Protea
# content:  9313 Protea  is a Main-belt Asteroid that was found on February 13, 1988 by E.
# ouput:  asteroid
#
#
# title:  6063 Jason
# content:  6063 Jason  is an Apollo asteroid, Venus-crosser asteroid, and Mars-crosser asteroid that was found on May 27, 1984 by Carolyn and Eugene Shoemaker at Palomar.
# ouput:  asteroid
#
#
# title:  6239 Minos
# content:  6239 Minos  is a Apollo asteroid and Venus-crosser asteroid that was found on August 31, 1989 by Carolyn S.
# ouput:  asteroid
#
#
# title:  Joe Hart
# content:  Joe Hart is an English footballer.
# ouput:  footballer
#
#
# title:  7092 Cadmus
# ...
# content:  1906 Naef  is a Main-belt Asteroid that was found on September 05, 1972 by P.
# ouput:  asteroid
#
#
# title:  1907 Rudneva
# content:  1907 Rudneva  is a Main-belt Asteroid that was found on September 11, 1972 by N.
# ouput:  asteroid
#
#
# title:  1908 Podeba
# content:  1908 Pobeda  is a Main-belt Asteroid that was found on September 11, 1972 by N.
# ouput:  asteroid
#
#
# title:  1912 Anubis
# content:  1912 Anubis  is a Main-belt Asteroid that was found on September 24, 1960 by Cornelis Johannes van Houten and Ingrid van Houten-Groeneveld at Leiden.
# ouput:  asteroid
#
#
# title:  19182 Pitz
# content:  19182 Pitz  is a Main-belt Asteroid that was found on October 7, 1991 by L.
# ouput:  asteroid
#
#
# title:  19433 Naftz
# content:  19433 Naftz  is a Main-belt Asteroid that was found on March 20, 1998 by the Lincoln Laboratory Near-Earth Asteroid Research Team at Socorro.
# ouput:  asteroid
#
#
# title:  19183 Amati
# content:  19183 Amati  is a Main-belt Asteroid that was found on October 5, 1991 by F.
# ouput:  asteroid
#
#
# title:  Naoki Chiba
# content:  Naoki Chiba  is a Japanese football player.
# ouput:  player
#
#
# title:  Daijiro Takakuwa
# content:  Daijiro Takakuwa  is a Japanese football player.
# ouput:  player
#
#
# title:  Toshiya Ishii
# content:  Toshiya Ishii  is a Japanese football player.
# ouput:  player
#
#
# title:  Toshiyuki Abe
# content:  Toshiyuki Abe  is a former Japanese football player.
# ouput:  player
#
#
# title:  Yasushi Fukunaga
# content:  Yasushi Fukunaga  is a former Japanese football player.
# ouput:  player
#
#
# title:  Teruo Iwamoto
# content:  Teruo Iwamoto  is a former Japanese football player.
# ouput:  player
#
#
# title:  Web services
# content:  A Web service is defined by the W3C as "a software system designed to support interoperable machine-to-machine interaction over a network".
# ouput:  None
#
#
# title:  Johannes Andreas Grib Fibiger
# content:  Nobel Prize stubs.
# ouput:  None
#
#
# title:  Julius Wagner-Jauregg
# content:  Nobel Prize stubs.
# ouput:  None
#
#
# title:  Pricing
# content:  Pricing is the creation of a price.
# ouput:  creation
#
#
# title:  Pubic bone
# content:  The pubic bone is one of the bones that make up the pelvis.
# ouput:  None
#
#
# title:  Kingdom of Poland (1916-1918)
# content:  This Kingdom of Poland was a proposed puppet state of German Empire.
# ouput:  None
#
#
# title:  Brown tree snake
# content:  The Brown tree snake  is an arboreal colubrid snake the lives in parts of coastal Australia, Papua New Guinea, and islands in northwestern Melanesia.
# ouput:  guinea
#
#
# title:  The Mighty B!
# content:  The Mighty B! is a Nickelodeon television programme made by Erik Wiese, Cynthia True, and Amy Poehler.
# ouput:  programme
#
#
# title:  Flogging
# content:  Flagellation or Flogging is hitting the human body with a whip .
# ouput:  None
#
#
# title:  Decency
# content:  Decency is behaving as social norms say.
# ouput:  None
#
#
# title:  History of Curitiba
# content:  The history of Curitiba has many different periods.
# ouput:  periods
#
#
# title:  Coimbra
# content:  Coimbra is a city in Portugal.
# ouput:  city
#
#
# title:  Corrientes
# content:  Corrientes is a city in Argentina.
# ouput:  city
#
#
# title:  Emerald ash borer
# content:  The emerald ash borer  is a shiny green beetle native to Asia.
# ouput:  native
#
#
# title:  Ratite
# content:  A ratite is a large, flightless bird, most of which are now extinct.
# ouput:  None
#
#
# title:  New Britain
# content:  New Britain is the largest island in the Bismarck Archipelago  of Papua New Guinea.
# ouput:  island
#
#
# title:  Gosford, New South Wales
# content:  Gosford is a city located on the Central Coast of New South Wales, Australia, approximately 80km north of the Sydney central business district.
# ouput:  city
#
#
# title:  Airlie Beach, Queensland
# content:  Airlie Beach is a town in the Whitsunday Region of Queensland, Australia.
# ouput:  town
#
#
# title:  Agama (genus)
# content:  An agama is any one of the various small, long-tailed, insect-eating lizards of the genus "Agama".
# ouput:  None
#
#
# title:  Hurricane Luis
# content:  Hurricane Luis was one of the most powerful storms of the very active 1995 Atlantic hurricane season.
# ouput:  None
#
#
# title:  Mossman, Queensland
# content:  Mossman is a town in north Queensland, Australia.
# ouput:  town
#
#
# title:  Satoshi Tsunami
# content:  Satoshi Tsunami  is a former Japanese football player.
# ouput:  player
#
#
# title:  Ryuji Kawai
# content:  Ryuji Kawai  is a Japanese football player.
# ouput:  player
#
#
# title:  Kiyotaka Matsui
# content:  Kiyotaka Matsui  is a former Japanese football player.
# ouput:  player
#
#
# title:  Ryūji Bando
# content:  Ryūji Bando  is a Japanese football player.
# ouput:  player
#
#
# title:  Yasutoshi Miura
# content:  Yasutoshi Miura  is a former Japanese football player.
# ouput:  player
#
#
# title:  Wim Jansen
# content:  Wim Jansen  is a former Dutch football player.
# ouput:  player
#
#
# title:  Yuji Nakazawa
# content:  Yuji Nakazawa  is a Japanese football player.
# ouput:  player
#
#
# title:  A.S. Roma
# content:  A.S.
# ouput:  None
#
#
# title:  A.S.D. Spezia Calcio 2008
# content:  A.S.D.
# ouput:  None
#
#
# title:  Cagliari Calcio
# content:  Cagliari Calcio is a football club which plays in Italy.
# ouput:  club
#
#
# title:  Hellas Verona F.C.
# content:  Hellas Verona F.C.
# ouput:  f.c
#
#
# title:  U.C. Sampdoria
# content:  U.C.
# ouput:  None
#
#
# title:  Romana
# content:  Romana, short for Romanadvoratrelundar, is a fictional character in the British science fiction television series "Doctor Who".
# ouput:  character
#
#
# title:  Rudolf II, Holy Roman Emperor
# content:  Rudolf II  was King of Hungary , King of Bohemia , Archduke of Austria , and Holy Roman Emperor .
# ouput:  None
#
#
# title:  Christine Anu
# content:  Christine Anu  is an Australian pop singer and actress.
# ouput:  singer
#
#
# title:  Commonwealth Scientific and Industrial Research Organisation
# content:  The Commonwealth Scientific and Industrial Research Organisation  is the national government body for scientific research in Australia.
# ouput:  body
#
#
# title:  Mission Beach, Queensland
# content:  Mission Beach is a small village along the Coral Sea in Queensland, Australia.
# ouput:  village
#
#
# title:  John Gould
# content:  John Gould  was an English ornithologist .
# ouput:  ornithologist
#
#
# title:  Red-violet
# content:  Red-violet is a deep shade of magenta.
# ouput:  shade
#
#
# title:  Philatelist materials
# content:  Philatelic materials are postage stamps, se-tenants, souvenir sheets, sheets of stamps, postal stationery, postal markings, and other indicia  that are objects of stamp collecting.
# ouput:  objects
#
#
# title:  Postage meter
# content:  A postage meter is an mechanical device used to create and apply physical evidence of postage to mailed matter.
# ouput:  device
#
#
# title:  Kiloware
# content:  Kiloware is a term for packages of postage stamps sold to stamp collectors by weight rather than by quantity, often in kilograms, hence the name.
# ouput:  term
#
#
# title:  Candidiasis
# content:  Candidiasis, often called yeast infection or thrush, is a type of infectious disease.
# ouput:  disease
#
#
# title:  GPU
# content:  A Graphics Processing Unit  is a RISC processor whose task is the calculation of graphical output for monitors.
# ouput:  calculation
#
#
# title:  1970 Atlantic hurricane season
# content:  The 1970 Atlantic hurricane season was the period of time in 1970 that tropical cyclones formed in Atlantic Ocean.
# ouput:  period
#
#
# title:  Orange Bowl
# content:  The Orange Bowl Game is a American college football bowl game at the Dolphin Stadium.
# ouput:  game
#
#
# title:  Gary Karr
# content:  Gary Karr , is an American classical double bass virtuoso and teacher.
# ouput:  virtuoso
#
#
# title:  1996 Atlantic hurricane season
# content:  The 1996 Atlantic hurricane season officially began on June 1, 1996, and lasted until November 30, 1996.
# ouput:  None
#
#
# title:  Nilotic
# content:  Nilotic is a word that refers to a number of people who speak Nilotic languages.
# ouput:  languages
#
#
# title:  Roman Patkoló
# content:  Roman Patkoló  is a Slovak virtuoso double bass player.
# ouput:  virtuoso
#
#
# title:  Healesville Sanctuary
# content:  Healesville Sanctuary, or the Sir Colin MacKenzie Fauna Park, is a zoo at Healesville in Victoria.
# ouput:  healesville
#
#
# title:  Tropical Storm Barry (2007)
# content:  Tropical Storm Barry was a quickly forming tropical cyclone that made landfall on Florida in early June, 2007.
# ouput:  None
#
#
# title:  2009 Atlantic hurricane season
# content:  The 2009 Atlantic hurricane season will be the period of 2009 when tropical cyclones will likely form in the Atlantic Ocean.
# ouput:  None
#
#
# title:  Tropical Depression Seven (2003)
# content:  Tropical Depression Seven was a weak tropical depression that formed near the northeast Florida coast.
# ouput:  depression
#
#
# title:  Mark Donaldson
# content:  Mark Donaldson is an Australian soldier who was given the Victoria Cross for Australia.
# ouput:  soldier
#
#
# title:  Greater Curitiba
# content:  The Greater Curitiba is a metropolitan area of Curitiba, the largest city in Southern Brazil; its the 118th largest metropolitan area in the world.
# ouput:  curitiba
#
#
# title:  Kero Kero Keroppi
# content:  Kero Kero Keroppi is a Japanese character of a frog.
# ouput:  character
#
#
# title:  Air Jordan
# content:  Air Jordan is basketball shoes that is produced by Nike, Incorporated.
# ouput:  basketball
#
#
# title:  West Ukrainian National Republic
# content:  The West Ukrainian National Republic  was a short-lived republic that existed in late 1918 and early 1919 in eastern Galicia, that claimed parts of Bukovina and Carpathian Ruthenia and included the cities of Lviv, Peremyshl', Kolomyia, and Stanislaviv.
# ouput:  republic
#
#
# title:  Lemko-Rusyn Republic
# content:  Lemko-Rusyn Republic or Ruska Narodna Respublika Lemkiv was founded in Florynka on December 5, 1918, in the aftermath of World War I, after the dissolution of the Austro-Hungarian Empire.
# ouput:  None
#
#
# title:  Komancza Republic
# content:  The Komancza Republic was an association of 30 Lemko villages, founded in eastern Lemkivshchyna in Komańcza on November 4, 1918.
# ouput:  association
#
#
# title:  Tatsuya Ishikawa
# content:  Tatsuya Ishikawa  is a Japanese football player.
# ouput:  player
#
#
# title:  Go Oiwa
# content:  Go Oiwa  is a Japanese football player.
# ouput:  player
#
#
# title:  Adrian Ilie
# content:  Adrian Ilie  is a former football player.
# ouput:  player
#
#
# title:  Takafumi Ogura
# content:  Takafumi Ogura  is a former Japanese football player.
# ouput:  player
#
#
# title:  Émerson Leão
# content:  Émerson Leão  is a former Brazilian football player.
# ouput:  player
#
#
# title:  Nobuhiro Takeda
# content:  Nobuhiro Takeda  is a former Japanese football player.
# ouput:  player
#
#
# title:  Valeri Nepomniachi
# content:  Valeri Nepomniachi  is a football manager.
# ouput:  manager
#
#
# title:  Ukrainian People's Republic
# content:  The Ukrainian People's Republic , in order to distinguish it from communist People's Republics) was a republic in part of the territory of modern Ukraine after the Russian Revolution, eventually headed by Symon Petliura.
# ouput:  republic
#
#
# title:  Galician Soviet Socialist Republic
# content:  Galician Soviet Socialist Republic  existed from July 8, 1920 to September 21, 1920 during the Polish-Soviet War within the area of the South-Western front of the Red Army.
# ouput:  None
#
#
# title:  Kingdom of Galicia and Lodomeria
# content:  The Kingdom of Galicia and Lodomeria "official" ) was a kingdom dependent to the Habsburg Monarchy, the Austrian Empire and Austria-Hungary from 1772 to 1917; independent from July 26, 1917 to November 14, 1918.
# ouput:  dependent
#
#
# title:  Republic of Central Lithuania
# content:  The Republic of Central Lithuania or Middle Lithuania , or simply Central Lithuania , was a short-lived political entity which did not gain international recognition.
# ouput:  entity
#
#
# title:  Eddie Thomson
# content:  Eddie Thomson  is a former Scottish football player.
# ouput:  player
#
#
# title:  Tatsuya Masushima
# content:  Tatsuya Masushima  is a Japanese football player.
# ouput:  player
#
#
# title:  Jozef Vengloš
# content:  Jozef Vengloš  is a former football player.
# ouput:  player
#
#
# title:  Adriano Leite Ribeiro
# content:  Adriano Leite Ribeiro  is a Brazilian football player.
# ouput:  player
#
#
# title:  Polish Underground State
# content:  The Polish Underground State  refers collectively to the underground resistance organizations in Poland during World War II, both military and civilian, loyal to the Polish Government in Exile in London.
# ouput:  None
#
#
# title:  Andrea Pirlo
# content:  Andrea Pirlo  is an Italian football player.
# ouput:  player
#
#
# The line:
#  has an incorrect number of tabs
# No solution was given for Army
# No solution was given for Wales
# No solution was given for Shovel
# No solution was given for Seam ripper
# No solution was given for Physical change
# No solution was given for Bath
# No solution was given for Ziggy Stardust
# No solution was given for Terry Gilliam
# No solution was given for Belize
# No solution was given for President of Russia
# No solution was given for Hillary Rodham Clinton
# No solution was given for Ilia
# No solution was given for Georges Brassens
# No solution was given for Edip Yuksel
# No solution was given for Hodgenville, Kentucky
# No solution was given for AC/DC
# No solution was given for São Tomé and Príncipe
# No solution was given for Disney Channel
# No solution was given for North and South
# No solution was given for Loreto Region
# No solution was given for Tropical cyclone
# No solution was given for Bismuth
# No solution was given for Pinocchio
# No solution was given for Wallonia
# No solution was given for Phylum
# No solution was given for Chipmunk
# No solution was given for Mollusc
# No solution was given for Isthmus
# No solution was given for Ritual
# No solution was given for John the Apostle
# No solution was given for Elle Macpherson
# No solution was given for Kookaburra Sport
# No solution was given for Alkmene
# No solution was given for Medusa (animal)
# No solution was given for Haiphong
# No solution was given for Crown-of-thorns starfish
# No solution was given for Pacific Islands
# No solution was given for Kampala
# No solution was given for Vaquita
# No solution was given for Mud
# No solution was given for Sondrio
# No solution was given for Jons Jacob Berzelius
# No solution was given for Western Digital
# No solution was given for K2
# No solution was given for Gran Colombia
# No solution was given for My Belarusy
# No solution was given for Great Fire of London
# No solution was given for Spike Spiegel
# No solution was given for Nu metal
# No solution was given for Orange (fruit)
# No solution was given for Toaster
# No solution was given for Moat
# No solution was given for Alex Trebek
# No solution was given for Smash (album)
# No solution was given for Shanty town
# No solution was given for Arthur de Gobineau
# No solution was given for Ledger line
# No solution was given for Pellagra
# No solution was given for Nagamaki
# No solution was given for Artillery
# No solution was given for Scone, Perth and Kinross
# No solution was given for Cerulean
# No solution was given for Nakhodka
# No solution was given for Paul Stanley (album)
# No solution was given for Joachim Löw
# No solution was given for Communication Studies
# No solution was given for 2029
# No solution was given for Bruges
# No solution was given for John Collins
# No solution was given for Lusaka
# No solution was given for Piston
# No solution was given for Manny Gamburyan
# No solution was given for Petros Duryan
# No solution was given for Onyx
# No solution was given for Thunderstorm
# No solution was given for Guwahati
# No solution was given for Hadith
# No solution was given for Hanami
# No solution was given for Magnetosphere
# No solution was given for Thebes, Greece
# No solution was given for Elegance
# No solution was given for General Motors railway station, Melbourne
# No solution was given for Escopetarra
# No solution was given for Hittites
# No solution was given for MotorStorm
# No solution was given for Doris Lessing
# No solution was given for Westdeutscher Rundfunk
# No solution was given for Kirkwood gap
# No solution was given for Fluid mechanics
# No solution was given for Phoenicia
# Comment :=>> Precision: 0.0 %
# Comment :=>> Recall: 0.0 %
# Simulated Grade (F0.5) :=>> 0.0 %

# %%
with open(result_file, 'w', encoding="utf-8") as output:
  for title, typ in dic.items():
    output.write(title + "\t" + typ + "\n")

# %%
eval_f1(gold_file, result_file)
# Out:
# The line:
#  has an incorrect number of tabs
# You got President of Russia wrong. Expected output:  leader
#  ,given: russia
#
# You got Hillary Rodham Clinton wrong. Expected output:  senator
#  ,given: states
#
# You got Edip Yuksel wrong. Expected output:  student
#  ,given: group
#
# You got Isthmus wrong. Expected output:  land
#  ,given: strip
#
# You got Ritual wrong. Expected output:  actions
#  ,given: set
#
# You got Nu metal wrong. Expected output:  music
#  ,given: style
#
# You got Moat wrong. Expected output:  water
#  ,given: body
#
# You got Cerulean wrong. Expected output:  colours
#  ,given: range
#
# You got Communication Studies wrong. Expected output:  study
#  ,given: college
#
# You got Hittites wrong. Expected output:  people
#  ,given: kingdom
#
# No solution was given for Army
# No solution was given for Seam ripper
# No solution was given for Ilia
# No solution was given for North and South
# No solution was given for Loreto Region
# No solution was given for Pinocchio
# No solution was given for Phylum
# No solution was given for John the Apostle
# No solution was given for Medusa (animal)
# No solution was given for K2
# No solution was given for Smash (album)
# No solution was given for 2029
# No solution was given for MotorStorm
# Comment :=>> Precision: 87.01298701298701 %
# Comment :=>> Recall: 74.44444444444444 %
# Simulated Grade (F0.5) :=>> 84.17085427135679 %
